# %%
pip install redis geopandas folium  geopy --index-url https://pypi.org/simple
# Out:
# Requirement already satisfied: redis in /Users/jmalik/.pyenv/versions/3.10.7/lib/python3.10/site-packages (5.0.2)
# Requirement already satisfied: geopandas in /Users/jmalik/.pyenv/versions/3.10.7/lib/python3.10/site-packages (0.14.3)
# Requirement already satisfied: folium in /Users/jmalik/.pyenv/versions/3.10.7/lib/python3.10/site-packages (0.16.0)
# Requirement already satisfied: geopy in /Users/jmalik/.pyenv/versions/3.10.7/lib/python3.10/site-packages (2.4.1)
# Requirement already satisfied: async-timeout>=4.0.3 in /Users/jmalik/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from redis) (4.0.3)
# Requirement already satisfied: fiona>=1.8.21 in /Users/jmalik/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from geopandas) (1.9.5)
# Requirement already satisfied: packaging in /Users/jmalik/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from geopandas) (23.2)
# Requirement already satisfied: pandas>=1.4.0 in /Users/jmalik/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from geopandas) (2.2.1)
# Requirement already satisfied: pyproj>=3.3.0 in /Users/jmalik/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=1.8.0 in /Users/jmalik/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from geopandas) (2.0.3)
# Requirement already satisfied: branca>=0.6.0 in /Users/jmalik/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from folium) (0.7.1)
# Requirement already satisfied: jinja2>=2.9 in /Users/jmalik/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in /Users/jmalik/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from folium) (1.26.2)
# Requirement already satisfied: requests in /Users/jmalik/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from folium) (2.31.0)
# Requirement already satisfied: xyzservices in /Users/jmalik/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from folium) (2023.10.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in /Users/jmalik/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from geopy) (2.0)
# Requirement already satisfied: attrs>=19.2.0 in /Users/jmalik/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (23.1.0)
# Requirement already satisfied: certifi in /Users/jmalik/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (2023.7.22)
# Requirement already satisfied: click~=8.0 in /Users/jmalik/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /Users/jmalik/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /Users/jmalik/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: six in /Users/jmalik/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (1.16.0)
# Requirement already satisfied: setuptools in /Users/jmalik/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (63.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jmalik/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/jmalik/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/jmalik/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from pandas>=1.4.0->geopandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/jmalik/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from pandas>=1.4.0->geopandas) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jmalik/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jmalik/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jmalik/.pyenv/versions/3.10.7/lib/python3.10/site-packages (from requests->folium) (2.0.7)
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import redis
import random
import time
import geopandas as gpd
import folium
from shapely.geometry import Point
import geopy.distance

# %%
# Control levers for simulation // Adjust here

NUM_OF_DRIVERS = 10
NUM_OF_RIDERS = 10
RADIUS = 1 # kms

# %%
# Start Redis

# Connect to Redis 
redis_client = redis.Redis(host='localhost', port=6379)

# %%
# Let's do a clean up 
redis_client.delete("available_drivers")
redis_client.delete("rider_queries")
# Out:
# 0

# %%
# Function for simulating driver check-ins in Delhi area (adjust coordinates)
def simulate_driver_checkins(num_drivers):
    drivers = []
    for i in range(num_drivers):
        longitude = 77.19  + random.uniform(-0.02, 0.02)  # Random around Delhi longitude
        latitude = 28.54  + random.uniform(-0.02, 0.02)   # Random around Delhi latitude
        driver_id = f"driver{i}"
        redis_client.geoadd("available_drivers", (longitude, latitude, driver_id))
        new_driver = {'driver_id': driver_id, 'longitude': longitude, 'latitude': latitude}
        print(new_driver)
        drivers.append(new_driver)
    return drivers

# %%
# Function for simulating rider queries 
def simulate_rider_queries(num_riders):
    riders = []
    for i in range(num_riders):
        rider_id = f"rider{i}"
        user_longitude = 77.19 + random.uniform(-0.02, 0.02)  # Random around Delhi longitude
        user_latitude = 28.54 + random.uniform(-0.02, 0.02)  # Random around Delhi latitude
        radius = RADIUS

        nearby_drivers = redis_client.georadius(
            "available_drivers", user_longitude, user_latitude, radius, unit='km', withdist=True
        )

        # Sort nearby_drivers by distance (ascending order)
        nearby_drivers.sort(key=lambda x: x[1])  # Sort by distance (second element in tuple)

        new_rider = {
            'rider_id': rider_id,
            'longitude': user_longitude,
            'latitude': user_latitude,
            'nearby_drivers': nearby_drivers
        }
        print(new_rider)
        riders.append(new_rider)

    return riders

# %%
# Simulate check-ins
drivers = simulate_driver_checkins(NUM_OF_DRIVERS)
# Out:
# {'driver_id': 'driver0', 'longitude': 77.2006203074985, 'latitude': 28.52911423902516}
# {'driver_id': 'driver1', 'longitude': 77.1991387495466, 'latitude': 28.53821858388841}
# {'driver_id': 'driver2', 'longitude': 77.18245656067984, 'latitude': 28.523506689544405}
# {'driver_id': 'driver3', 'longitude': 77.18351983505327, 'latitude': 28.553919311068956}
# {'driver_id': 'driver4', 'longitude': 77.1905731564784, 'latitude': 28.526580808362475}
# {'driver_id': 'driver5', 'longitude': 77.20926102511525, 'latitude': 28.559446731610844}
# {'driver_id': 'driver6', 'longitude': 77.20030407594389, 'latitude': 28.547075308520988}
# {'driver_id': 'driver7', 'longitude': 77.2024447595539, 'latitude': 28.533051571443583}
# {'driver_id': 'driver8', 'longitude': 77.19793214027027, 'latitude': 28.549358799468944}
# {'driver_id': 'driver9', 'longitude': 77.18883226678183, 'latitude': 28.536713078381837}

# %%
# Simulate rider queries
riders = simulate_rider_queries(NUM_OF_RIDERS)
# Out:
# {'rider_id': 'rider0', 'longitude': 77.20801635265057, 'latitude': 28.557640185927745, 'nearby_drivers': [[b'driver5', 0.2349]]}
# {'rider_id': 'rider1', 'longitude': 77.18476921871225, 'latitude': 28.549560297899994, 'nearby_drivers': [[b'driver3', 0.5]]}
# {'rider_id': 'rider2', 'longitude': 77.18804412064091, 'latitude': 28.543499621940192, 'nearby_drivers': [[b'driver9', 0.7587]]}
# {'rider_id': 'rider3', 'longitude': 77.18915225682217, 'latitude': 28.543412472443443, 'nearby_drivers': [[b'driver9', 0.7458]]}
# {'rider_id': 'rider4', 'longitude': 77.20289519761985, 'latitude': 28.552427932094133, 'nearby_drivers': [[b'driver8', 0.593], [b'driver6', 0.647], [b'driver5', 0.9982]]}
# {'rider_id': 'rider5', 'longitude': 77.17868223284201, 'latitude': 28.556618360634538, 'nearby_drivers': [[b'driver3', 0.5597]]}
# {'rider_id': 'rider6', 'longitude': 77.19281344150588, 'latitude': 28.52925528275391, 'nearby_drivers': [[b'driver4', 0.3693], [b'driver0', 0.763], [b'driver9', 0.9162]]}
# {'rider_id': 'rider7', 'longitude': 77.1983321818392, 'latitude': 28.522869211339195, 'nearby_drivers': [[b'driver0', 0.7297], [b'driver4', 0.8635]]}
# {'rider_id': 'rider8', 'longitude': 77.20889669408626, 'latitude': 28.548648391274806, 'nearby_drivers': [[b'driver6', 0.8577]]}
# {'rider_id': 'rider9', 'longitude': 77.18154341497957, 'latitude': 28.52275658781113, 'nearby_drivers': [[b'driver2', 0.1221], [b'driver4', 0.9795]]}

# %%
df_drivers = gpd.GeoDataFrame(drivers, geometry=[Point(row['longitude'], row['latitude']) for row in drivers])
df_riders = gpd.GeoDataFrame(riders, geometry=[Point(row['longitude'], row['latitude']) for row in riders])

# %%
# Create a map
center_location = (df_drivers.geometry.y.mean(), df_drivers.geometry.x.mean())  # Average location
map = folium.Map(location=center_location, zoom_start=15)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_863861d75a72304f3c658e0e588a5114 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_863861d75a72304f3c658e0e588a5114&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_863861d75a72304f3c658e0e588a5114 = L.map(
#                 &quot;map_863861d75a72304f3c658e0e588a5114&quot;,
#                 {
#                     center: [28.539698512131565, 77.19550828769216],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_93687448457998a66eee0932e4845c34 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_93687448457998a66eee0932e4845c34.addTo(map_863861d75a72304f3c658e0e588a5114);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map = folium.Map(location=center_location, zoom_start=15, tiles="CartoDB Positron")

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_98d3f091d3c545470bcfdb8c87bffa65 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_98d3f091d3c545470bcfdb8c87bffa65&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_98d3f091d3c545470bcfdb8c87bffa65 = L.map(
#                 &quot;map_98d3f091d3c545470bcfdb8c87bffa65&quot;,
#                 {
#                     center: [28.539698512131565, 77.19550828769216],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_70b3e93c245eb4a5e115d047e2e41130 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_70b3e93c245eb4a5e115d047e2e41130.addTo(map_98d3f091d3c545470bcfdb8c87bffa65);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Add driver markers with Taxi emoji 🚕
for _, row in df_drivers.iterrows():
    driver_emoji = "🚕"
    driver_id = row["driver_id"]
    folium.Marker(location=[row.geometry.y, row.geometry.x], icon=folium.DivIcon(
        icon_size=(25,25),
        icon_anchor=(0,0),
        html=f"""
            <div style="font-size: 30px;">{driver_emoji}</div>
            <div style="font-size: 15px; font-weight: bold;">{driver_id}</div>
        """
    )
        ).add_to(map)


# Add rider markers with 🙋‍♂️ or 🙋‍♀️ 
for _, row in df_riders.iterrows():
    # because diversity is important
    rider_emoji = random.choice(["🙋‍♂️", "🙋‍♀️"])
    rider_id = row["rider_id"] 

    folium.Marker(location=[row.geometry.y, row.geometry.x],icon=folium.DivIcon(
        icon_size=(25,25),
        icon_anchor=(0,0),
       html=f"""
            <div style="font-size: 30px;">{rider_emoji}</div>
            <div style="font-size: 15px; font-weight: bold;">{rider_id}</div>
        """
    )
        ).add_to(map)
map.fit_bounds(map.get_bounds())

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_98d3f091d3c545470bcfdb8c87bffa65 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_98d3f091d3c545470bcfdb8c87bffa65&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_98d3f091d3c545470bcfdb8c87bffa65 = L.map(
#                 &quot;map_98d3f091d3c545470bcfdb8c87bffa65&quot;,
#                 {
#                     center: [28.539698512131565, 77.19550828769216],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_70b3e93c245eb4a5e115d047e2e41130 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_70b3e93c245eb4a5e115d047e2e41130.addTo(map_98d3f091d3c545470bcfdb8c87bffa65);
#
#
#             tile_layer_70b3e93c245eb4a5e115d047e2e41130.addTo(map_98d3f091d3c545470bcfdb8c87bffa65);
#
#
#             var marker_82526dec465b6791359ece6fa54066c8 = L.marker(
#                 [28.52911423902516, 77.2006203074985],
#                 {}
#             ).addTo(map_98d3f091d3c545470bcfdb8c87bffa65);
#
#
#             var div_icon_cef3e57770a9b2b611bdace2d3523960 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n            \u003cdiv style=\&quot;font-size: 30px;\&quot;\u003e\ud83d\ude95\u003c/div\u003e\n            \u003cdiv style=\&quot;font-size: 15px; font-weight: bold;\&quot;\u003edriver0\u003c/div\u003e\n        &quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [25, 25]});
#             marker_82526dec465b6791359ece6fa54066c8.setIcon(div_icon_cef3e57770a9b2b611bdace2d3523960);
#
#
#             var marker_2a08d5148326162169aeb9f104b1d08b = L.marker(
#                 [28.53821858388841, 77.1991387495466],
#                 {}
#             ).addTo(map_98d3f091d3c545470bcfdb8c87bffa65);
#
#
#             var div_icon_6e65677b2be766eac3c7cde781cdae4f = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n            \u003cdiv style=\&quot;font-size: 30px;\&quot;\u003e\ud83d\ude95\u003c/div\u003e\n            \u003cdiv style=\&quot;font-size: 15px; font-weight: bold;\&quot;\u003edriver1\u003c/div\u003e\n        &quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [25, 25]});
#             marker_2a08d5148326162169aeb9f104b1d08b.setIcon(div_icon_6e65677b2be766eac3c7cde781cdae4f);
#
#
#             var marker_24695d1af9d2c25c28e7ffd9ed27ec87 = L.marker(
#                 [28.523506689544405, 77.18245656067984],
#                 {}
#             ).addTo(map_98d3f091d3c545470bcfdb8c87bffa65);
#
#
#             var div_icon_bb3a3183b25e0806cdd40d2f78d75f2e = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n            \u003cdiv style=\&quot;font-size: 30px;\&quot;\u003e\ud83d\ude95\u003c/div\u003e\n            \u003cdiv style=\&quot;font-size: 15px; font-weight: bold;\&quot;\u003edriver2\u003c/div\u003e\n        &quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [25, 25]});
#             marker_24695d1af9d2c25c28e7ffd9ed27ec87.setIcon(div_icon_bb3a3183b25e0806cdd40d2f78d75f2e);
#
#
#             var marker_05c9db48921eb30fd15fb49fd0e1d196 = L.marker(
#                 [28.553919311068956, 77.18351983505327],
#                 {}
#             ).addTo(map_98d3f091d3c545470bcfdb8c87bffa65);
#
#
#             var div_icon_759523dc848e8acfc12bf0cfcb02b1ad = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n            \u003cdiv style=\&quot;font-size: 30px;\&quot;\u003e\ud83d\ude95\u003c/div\u003e\n            \u003cdiv style=\&quot;font-size: 15px; font-weight: bold;\&quot;\u003edriver3\u003c/div\u003e\n        &quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [25, 25]});
#             marker_05c9db48921eb30fd15fb49fd0e1d196.setIcon(div_icon_759523dc848e8acfc12bf0cfcb02b1ad);
#
#
#             var marker_48a8c2b2d91bf9fbca133ab3ff567097 = L.marker(
#                 [28.526580808362475, 77.1905731564784],
#                 {}
#             ).addTo(map_98d3f091d3c545470bcfdb8c87bffa65);
#
#
#             var div_icon_8e7b01a1a70c8b32afec59df120e3cae = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n            \u003cdiv style=\&quot;font-size: 30px;\&quot;\u003e\ud83d\ude95\u003c/div\u003e\n            \u003cdiv style=\&quot;font-size: 15px; font-weight: bold;\&quot;\u003edriver4\u003c/div\u003e\n        &quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [25, 25]});
#             marker_48a8c2b2d91bf9fbca133ab3ff567097.setIcon(div_icon_8e7b01a1a70c8b32afec59df120e3cae);
#
#
#             var marker_245841bae65e596435ca55a9f8b7bea8 = L.marker(
#                 [28.559446731610844, 77.20926102511525]

# %%
def draw_match_line(map, rider_location, driver_location):
    # Extract coordinates from Point objects (if needed)
    if isinstance(rider_location, Point):
        rider_coords = [rider_location.y, rider_location.x]
    else:
        rider_coords = rider_location

    driver_coords = driver_location

    # Calculate distance (in kilometers)
    distance = geopy.distance.distance(rider_coords, driver_coords).km

    # Create polyline with distance label
    folium.PolyLine(
        locations=[rider_coords, driver_coords], color="green", weight=4, opacity=1, dashArray="5, 5"
    ).add_to(map)

# %%
# Simulation time!
# In an ideal world when nearest driver always accept your ride.
# Match riders to drivers and draw lines, with logs
matched_drivers = set()

for i, rider in df_riders.iterrows():
    rider_id = rider["rider_id"]
    print("-"*10)
    print(f"Time: t{i}")
    print("-"*10)
    print(f"{rider_id} looking for a ride...")

    nearby_drivers = rider["nearby_drivers"]
    nearby_drivers.sort(key=lambda x: x[1])

    print(f"Drivers found nearby: {nearby_drivers}")

    found_driver = False
    for driver_info, distance in nearby_drivers:
        driver_id = driver_info.decode()
        if driver_id not in matched_drivers:
            matched_drivers.add(driver_id)
            found_driver = True
            print(f"Ride matched to: {driver_id}")
            break

    # If no available driver is found, draw a red circle around the rider
    if not found_driver:
        print(f"No driver found for {rider_id}!")
        folium.Circle(
            location=[rider.geometry.y, rider.geometry.x],
            radius=RADIUS*1000,  # Adjust radius as needed
            color="red",
            fill=True,
            fill_color="red",
            fill_opacity=0.1,
        ).add_to(map)
        continue

    if driver_id in matched_drivers:
        driver_row = df_drivers[df_drivers["driver_id"] == driver_id].iloc[0]
        driver_location = [driver_row.geometry.y, driver_row.geometry.x]  # Extract coordinates
        draw_match_line(map, rider.geometry, driver_location)
        print("Ride is On!\n")

# Display the map with lines
map
# Out:
# ----------
# Time: t0
# ----------
# rider0 looking for a ride...
# Drivers found nearby: [[b'driver5', 0.2349]]
# Ride matched to: driver5
# Ride is On!
#
# ----------
# Time: t1
# ----------
# rider1 looking for a ride...
# Drivers found nearby: [[b'driver3', 0.5]]
# Ride matched to: driver3
# Ride is On!
#
# ----------
# Time: t2
# ----------
# rider2 looking for a ride...
# Drivers found nearby: [[b'driver9', 0.7587]]
# Ride matched to: driver9
# Ride is On!
#
# ----------
# Time: t3
# ----------
# rider3 looking for a ride...
# Drivers found nearby: [[b'driver9', 0.7458]]
# No driver found for rider3!
# ----------
# Time: t4
# ----------
# rider4 looking for a ride...
# Drivers found nearby: [[b'driver8', 0.593], [b'driver6', 0.647], [b'driver5', 0.9982]]
# Ride matched to: driver8
# Ride is On!
#
# ----------
# Time: t5
# ----------
# rider5 looking for a ride...
# Drivers found nearby: [[b'driver3', 0.5597]]
# No driver found for rider5!
# ----------
# Time: t6
# ----------
# rider6 looking for a ride...
# Drivers found nearby: [[b'driver4', 0.3693], [b'driver0', 0.763], [b'driver9', 0.9162]]
# Ride matched to: driver4
# Ride is On!
#
# ----------
# Time: t7
# ----------
# rider7 looking for a ride...
# Drivers found nearby: [[b'driver0', 0.7297], [b'driver4', 0.8635]]
# Ride matched to: driver0
# Ride is On!
#
# ----------
# Time: t8
# ----------
# rider8 looking for a ride...
# Drivers found nearby: [[b'driver6', 0.8577]]
# Ride matched to: driver6
# Ride is On!
#
# ----------
# Time: t9
# ----------
# rider9 looking for a ride...
# Drivers found nearby: [[b'driver2', 0.1221], [b'driver4', 0.9795]]
# Ride matched to: driver2
# Ride is On!
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_98d3f091d3c545470bcfdb8c87bffa65 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_98d3f091d3c545470bcfdb8c87bffa65&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_98d3f091d3c545470bcfdb8c87bffa65 = L.map(
#                 &quot;map_98d3f091d3c545470bcfdb8c87bffa65&quot;,
#                 {
#                     center: [28.539698512131565, 77.19550828769216],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_70b3e93c245eb4a5e115d047e2e41130 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_70b3e93c245eb4a5e115d047e2e41130.addTo(map_98d3f091d3c545470bcfdb8c87bffa65);
#
#
#             tile_layer_70b3e93c245eb4a5e115d047e2e41130.addTo(map_98d3f091d3c545470bcfdb8c87bffa65);
#
#
#             var marker_82526dec465b6791359ece6fa54066c8 = L.marker(
#                 [28.52911423902516, 77.2006203074985],
#                 {}
#             ).addTo(map_98d3f091d3c545470bcfdb8c87bffa65);
#
#
#             var div_icon_cef3e57770a9b2b611bdace2d3523960 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n            \u003cdiv style=\&quot;font-size: 30px;\&quot;\u003e\ud83d\ude95\u003c/div\u003e\n            \u003cdiv style=\&quot;font-size: 15px; font-weight: bold;\&quot;\u003edriver0\u003c/div\u003e\n        &quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [25, 25]});
#             marker_82526dec465b6791359ece6fa54066c8.setIcon(div_icon_cef3e57770a9b2b611bdace2d3523960);
#
#
#             var marker_2a08d5148326162169aeb9f104b1d08b = L.marker(
#                 [28.53821858388841, 77.1991387495466],
#                 {}
#             ).addTo(map_98d3f091d3c545470bcfdb8c87bffa65);
#
#
#             var div_icon_6e65677b2be766eac3c7cde781cdae4f = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n            \u003cdiv style=\&quot;font-size: 30px;\&quot;\u003e\ud83d\ude95\u003c/div\u003e\n            \u003cdiv style=\&quot;font-size: 15px; font-weight: bold;\&quot;\u003edriver1\u003c/div\u003e\n        &quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [25, 25]});
#             marker_2a08d5148326162169aeb9f104b1d08b.setIcon(div_icon_6e65677b2be766eac3c7cde781cdae4f);
#
#
#             var marker_24695d1af9d2c25c28e7ffd9ed27ec87 = L.marker(
#                 [28.523506689544405, 77.18245656067984],
#                 {}
#             ).addTo(map_98d3f091d3c545470bcfdb8c87bffa65);
#
#
#             var div_icon_bb3a3183b25e0806cdd40d2f78d75f2e = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n            \u003cdiv style=\&quot;font-size: 30px;\&quot;\u003e\ud83d\ude95\u003c/div\u003e\n            \u003cdiv style=\&quot;font-size: 15px; font-weight: bold;\&quot;\u003edriver2\u003c/div\u003e\n        &quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [25, 25]});
#             marker_24695d1af9d2c25c28e7ffd9ed27ec87.setIcon(div_icon_bb3a3183b25e0806cdd40d2f78d75f2e);
#
#
#             var marker_05c9db48921eb30fd15fb49fd0e1d196 = L.marker(
#                 [28.553919311068956, 77.18351983505327],
#                 {}
#             ).addTo(map_98d3f091d3c545470bcfdb8c87bffa65);
#
#
#             var div_icon_759523dc848e8acfc12bf0cfcb02b1ad = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n            \u003cdiv style=\&quot;font-size: 30px;\&quot;\u003e\ud83d\ude95\u003c/div\u003e\n            \u003cdiv style=\&quot;font-size: 15px; font-weight: bold;\&quot;\u003edriver3\u003c/div\u003e\n        &quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [25, 25]});
#             marker_05c9db48921eb30fd15fb49fd0e1d196.setIcon(div_icon_759523dc848e8acfc12bf0cfcb02b1ad);
#
#
#             var marker_48a8c2b2d91bf9fbca133ab3ff567097 = L.marker(
#                 [28.526580808362475, 77.1905731564784],
#                 {}
#             ).addTo(map_98d3f091d3c545470bcfdb8c87bffa65);
#
#
#             var div_icon_8e7b01a1a70c8b32afec59df120e3cae = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n            \u003cdiv style=\&quot;font-size: 30px;\&quot;\u003e\ud83d\ude95\u003c/div\u003e\n            \u003cdiv style=\&quot;font-size: 15px; font-weight: bold;\&quot;\u003edriver4\u003c/div\u003e\n        &quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [25, 25]});
#             marker_48a8c2b2d91bf9fbca133ab3ff567097.setIcon(div_icon_8e7b01a1a70c8b32afec59df120e3cae);
#
#
#             var marker_245841bae65e596435ca55a9f8b7bea8 = L.marker(
#                 [28.559446731610844, 77.20926102511525]
